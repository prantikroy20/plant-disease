# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # Test set Image Processing

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
class_name = validation_set.class_names
print(class_name)
# Out:
# Found 17572 files belonging to 38 classes.
# ...

# %% [markdown]
# # Loading Model

# %%
cnn = tf.keras.models.load_model('trained_model.keras')

# %% [markdown]
# # Visualising and Performing Prediction on Single image

# %%
import cv2

# %%
#Test Image Visualization
import cv2
image_path = 'test/test/AppleCedarRust1.JPG'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step

# %%
print(predictions)
# Out:
# [[9.74649652e-07 4.36027436e-09 9.85482454e-01 6.83728585e-09
#   5.17741334e-08 1.53745304e-07 5.94589655e-11 2.69768350e-07
#   3.62024383e-10 6.23594865e-09 1.71540282e-11 3.94779408e-06
#   2.92825604e-08 1.48214411e-07 3.43597151e-07 5.00556268e-07
#   2.03605334e-04 4.11402912e-09 9.55523888e-07 4.05300568e-07
#   6.96417812e-09 7.45077031e-08 6.43550990e-08 1.69839240e-07
#   3.41459439e-09 3.95012165e-08 1.45056820e-08 1.38228129e-09
#   1.41203152e-02 1.18804146e-05 1.34670745e-05 1.47535744e-08
#   4.23867241e-05 2.03614281e-08 2.63191905e-05 9.07774593e-05
#   5.46825092e-08 5.99907310e-07]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 2

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Test Image Visualization
import cv2
image_path = image_path = r'C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\ravi test.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128`,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
print(predictions)
# Out:
# [[7.84982967e-06 1.15776606e-06 1.19696744e-01 2.54375860e-04
#   9.34212403e-06 2.88858981e-04 3.03874526e-06 1.34416462e-06
#   9.87547537e-08 1.64009107e-05 6.64344498e-07 4.54592418e-06
#   3.32736613e-06 1.01281458e-07 6.91398805e-09 1.48603449e-05
#   1.71525899e-05 7.76310626e-04 7.34082278e-05 2.50670098e-04
#   1.35748115e-08 6.24998393e-06 8.77325438e-05 9.72779188e-03
#   6.48350351e-06 5.69949805e-07 1.75579669e-04 1.36796828e-07
#   2.87781495e-05 5.00839378e-05 1.56755894e-01 2.98568487e-01
#   5.25003343e-05 7.58705355e-05 1.18750313e-05 4.13006008e-01
#   1.49168427e-05 1.08120903e-05]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 35

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# r'C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\ravi test.jpg'

# %% [raw]
# "C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\ravi test 2.jpg"

# %%
r'C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\ravi test 2.jpg'
r'C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\tomato healthy test.jpg'

# %%
import os
print(os.path.exists(r'C:\Users\User\Downloads\plant-disease-ditection-copy\test\test\ravi test 2.jpg'))  # Should return True

# %%
#Test Image Visualization
import cv2
image_path = r"C:\Users\User\Downloads\plant-disease-ditection-copy\train\Tomato___healthy\edd71d50-a50f-4f36-af69-6c9df7c040af___GH_HL Leaf 484.1.JPG"
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
print(predictions)
# Out:
# [[4.7395721e-07 9.7974322e-09 2.2225561e-07 1.2193868e-04 7.9948941e-06
#   1.6049532e-07 6.3750818e-08 5.3538858e-09 3.4027017e-09 9.3266719e-09
#   4.9804164e-08 1.2428366e-09 1.9264745e-09 2.1835385e-10 8.8102441e-09
#   9.3009888e-08 2.8298089e-07 4.4677563e-08 1.0439932e-09 2.4745802e-06
#   8.0417088e-08 8.7538794e-09 7.3640234e-07 7.4133297e-08 6.9777718e-07
#   5.3254809e-07 2.1200972e-08 6.4605103e-08 2.4604435e-07 2.6261073e-08
#   3.1229013e-06 5.4470233e-06 1.3917910e-06 3.4676509e-07 6.6008247e-06
#   2.6765548e-08 8.8255554e-08 9.9984670e-01]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 37

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()
